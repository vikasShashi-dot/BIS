# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasShashi-dot/BIS/blob/main/Lab5/CSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np

W = 50
weights = [10, 20, 30, 40, 50]
values = [60, 100, 120, 140, 160]
n_items = len(weights)

num_cuckoos = 50
max_iter = 100
pa = 0.25

cuckoos = np.random.randint(2, size=(num_cuckoos, n_items))

def fitness(cuckoo):
    total_weight = sum(cuckoo[i] * weights[i] for i in range(n_items))
    total_value = sum(cuckoo[i] * values[i] for i in range(n_items))
    if total_weight > W:
        return 0
    return total_value

def levy_flight(cuckoo, alpha=1.0):
    step_size = np.random.normal(0, 1, size=cuckoo.shape)
    new_cuckoo = cuckoo + alpha * step_size
    new_cuckoo = np.clip(new_cuckoo, 0, 1)
    return np.round(new_cuckoo)

for iteration in range(max_iter):
    fitness_values = np.array([fitness(cuckoo) for cuckoo in cuckoos])
    best_index = np.argmax(fitness_values)
    best_cuckoo = cuckoos[best_index]
    best_fitness = fitness_values[best_index]

    for i in range(num_cuckoos):
        if random.random() > pa:
            cuckoos[i] = levy_flight(cuckoos[i])

    new_fitness_values = np.array([fitness(cuckoo) for cuckoo in cuckoos])

    for i in range(num_cuckoos):
        if new_fitness_values[i] > fitness_values[i]:
            cuckoos[i] = cuckoos[i]

    print(f"Iteration {iteration+1}: Best Fitness = {best_fitness}")

best_solution = best_cuckoo
selected_items = [i for i in range(n_items) if best_solution[i] == 1]
selected_values = [values[i] for i in selected_items]
selected_weights = [weights[i] for i in selected_items]

print("\nBest Solution:")
print("Selected Items:", selected_items)
print("Selected Values:", selected_values)
print("Selected Weights:", selected_weights)
print("Total Weight:", sum(selected_weights))
print("Total Value:", sum(selected_values))
print("Best Fitness Value:", best_fitness)
# Out:
# Iteration 1: Best Fitness = 220
# Iteration 2: Best Fitness = 220
# Iteration 3: Best Fitness = 220
# Iteration 4: Best Fitness = 220
# Iteration 5: Best Fitness = 220
# Iteration 6: Best Fitness = 220
# Iteration 7: Best Fitness = 200
# Iteration 8: Best Fitness = 220
# Iteration 9: Best Fitness = 220
# Iteration 10: Best Fitness = 220
# Iteration 11: Best Fitness = 220
# Iteration 12: Best Fitness = 220
# Iteration 13: Best Fitness = 200
# Iteration 14: Best Fitness = 200
# Iteration 15: Best Fitness = 220
# Iteration 16: Best Fitness = 220
# Iteration 17: Best Fitness = 180
# Iteration 18: Best Fitness = 220
# Iteration 19: Best Fitness = 220
# Iteration 20: Best Fitness = 220
# Iteration 21: Best Fitness = 220
# Iteration 22: Best Fitness = 220
# Iteration 23: Best Fitness = 220
# Iteration 24: Best Fitness = 220
# Iteration 25: Best Fitness = 220
# Iteration 26: Best Fitness = 160
# Iteration 27: Best Fitness = 160
# Iteration 28: Best Fitness = 220
# Iteration 29: Best Fitness = 200
# Iteration 30: Best Fitness = 220
# Iteration 31: Best Fitness = 220
# Iteration 32: Best Fitness = 220
# Iteration 33: Best Fitness = 200
# Iteration 34: Best Fitness = 220
# Iteration 35: Best Fitness = 220
# Iteration 36: Best Fitness = 220
# Iteration 37: Best Fitness = 220
# Iteration 38: Best Fitness = 180
# Iteration 39: Best Fitness = 220
# Iteration 40: Best Fitness = 220
# Iteration 41: Best Fitness = 220
# Iteration 42: Best Fitness = 220
# Iteration 43: Best Fitness = 220
# Iteration 44: Best Fitness = 220
# Iteration 45: Best Fitness = 220
# Iteration 46: Best Fitness = 220
# Iteration 47: Best Fitness = 220
# Iteration 48: Best Fitness = 220
# Iteration 49: Best Fitness = 220
# Iteration 50: Best Fitness = 220
# Iteration 51: Best Fitness = 220
# Iteration 52: Best Fitness = 220
# Iteration 53: Best Fitness = 220
# Iteration 54: Best Fitness = 160
# Iteration 55: Best Fitness = 200
# Iteration 56: Best Fitness = 220
# Iteration 57: Best Fitness = 220
# Iteration 58: Best Fitness = 220
# Iteration 59: Best Fitness = 220
# Iteration 60: Best Fitness = 220
# Iteration 61: Best Fitness = 220
# Iteration 62: Best Fitness = 220
# Iteration 63: Best Fitness = 220
# Iteration 64: Best Fitness = 220
# Iteration 65: Best Fitness = 220
# Iteration 66: Best Fitness = 220
# Iteration 67: Best Fitness = 220
# Iteration 68: Best Fitness = 220
# Iteration 69: Best Fitness = 220
# Iteration 70: Best Fitness = 220
# Iteration 71: Best Fitness = 200
# Iteration 72: Best Fitness = 220
# Iteration 73: Best Fitness = 220
# Iteration 74: Best Fitness = 220
# Iteration 75: Best Fitness = 180
# Iteration 76: Best Fitness = 220
# Iteration 77: Best Fitness = 220
# Iteration 78: Best Fitness = 200
# Iteration 79: Best Fitness = 220
# Iteration 80: Best Fitness = 220
# Iteration 81: Best Fitness = 220
# Iteration 82: Best Fitness = 160
# Iteration 83: Best Fitness = 220
# Iteration 84: Best Fitness = 220
# Iteration 85: Best Fitness = 220
# Iteration 86: Best Fitness = 220
# Iteration 87: Best Fitness = 220
# Iteration 88: Best Fitness = 220
# Iteration 89: Best Fitness = 220
# Iteration 90: Best Fitness = 220
# Iteration 91: Best Fitness = 220
# Iteration 92: Best Fitness = 220
# Iteration 93: Best Fitness = 220
# Iteration 94: Best Fitness = 220
# Iteration 95: Best Fitness = 220
# Iteration 96: Best Fitness = 220
# Iteration 97: Best Fitness = 220
# Iteration 98: Best Fitness = 220
# Iteration 99: Best Fitness = 200
# Iteration 100: Best Fitness = 220
#
# Best Solution:
# Selected Items: [1, 2]
# Selected Values: [100, 120]
# Selected Weights: [20, 30]
# Total Weight: 50
# Total Value: 220
# Best Fitness Value: 220
